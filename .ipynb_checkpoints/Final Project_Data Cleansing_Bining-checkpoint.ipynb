# %% [markdown]
# # Data Cleansing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
from datetime import datetime

# %%
Chicago_TA = pd.read_csv("./Resources/Web_Scraping_Data_Raw/Chicago_review_data.csv")
NYC_TA = pd.read_csv("./Resources/Web_Scraping_Data_Raw/NYC_review_data.csv")
DC_TA = pd.read_csv("./Resources/Web_Scraping_Data_Raw/DC_review_data.csv")

NYC_Yelp = pd.read_csv("./Resources/Web_Scraping_Data_Raw/Newyork_yelp_review.csv", encoding="iso-8859-1")
DC_Yelp = pd.read_csv("./Resources/Web_Scraping_Data_Raw/washington_review.csv", encoding="iso-8859-1")

# %%
# Add City name
Chicago_TA["City"] = "Chicago"
NYC_TA["City"] = "NYC"
DC_TA["City"] = "DC"
NYC_Yelp["City"] = "NYC"
DC_Yelp["City"] = "DC"

# %%
Merge_table_TA = Chicago_TA.append([NYC_TA, DC_TA])
Merge_table_TA["Review_Text"] = Merge_table_TA["Entry_Quote"] + " " + Merge_table_TA["Entry_Content"]
Merge_table_TA = Merge_table_TA.rename(columns={"Entry_Date": "Review_Date",
                                  "review_text":"Review_Text"})

Merge_table_TA.loc[Merge_table_TA["Stars"] == 1, "Class"] = "Negative"
Merge_table_TA.loc[Merge_table_TA["Stars"] == 2, "Class"] = "Negative"
Merge_table_TA.loc[Merge_table_TA["Stars"] == 3, "Class"] = "Neutral"
Merge_table_TA.loc[Merge_table_TA["Stars"] == 4, "Class"] = "Positive"
Merge_table_TA.loc[Merge_table_TA["Stars"] == 5, "Class"] = "Positive"

Merge_table_TA["Review_Source"] = "TripAdvisor"

Merge_table_TA = Merge_table_TA[['City', 'Stars', 'Class', 'Review_Source', 'Review_Date', 'Review_Text']]

Merge_table_TA.to_csv("./Resources/Merge_table_TripAdvisor.csv", index=False)

Merge_table_TA.head()
# Out:
#       City  Stars     Class Review_Source Review_Date  \
# 0  Chicago      5  Positive   TripAdvisor  04/15/2019
# 1  Chicago      1  Negative   TripAdvisor  03/08/2019
# 2  Chicago      1  Negative   TripAdvisor  02/25/2019
# 3  Chicago      5  Positive   TripAdvisor  02/12/2019
# 4  Chicago      2  Negative   TripAdvisor  01/23/2019
#
#                                          Review_Text
# 0  Must do when in Chicago! We loved renting thes...
# 1  Dissapointed Very disappointed with Divvy Bike...
# 2  Dishonest company.. Terrible customer service ...
# 3  Practical, eco-friendly transportation Awesome...
# 4  Service has gone way down. Not reliable anymor...

# %%
Merge_table_TA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 886 entries, 0 to 325
# Data columns (total 6 columns):
# City             886 non-null object
# Stars            886 non-null int64
# Class            886 non-null object
# Review_Source    886 non-null object
# Review_Date      886 non-null object
# Review_Text      886 non-null object
# dtypes: int64(1), object(5)
# memory usage: 48.5+ KB

# %%
Merge_table_Yelp = NYC_Yelp.append(DC_Yelp)
Merge_table_Yelp = Merge_table_Yelp.drop(Merge_table_Yelp.columns[0], axis=1)
Merge_table_Yelp = Merge_table_Yelp.rename(columns={"review_ratings":"Stars",
                                  "review_date": "Review_Date",
                                  "review_text":"Review_Text"})

Merge_table_Yelp["Review_Date"] = pd.to_datetime(Merge_table_Yelp["Review_Date"], format='%m/%d/%Y').apply(lambda x: x.strftime('%m/%d/%Y'))

Merge_table_Yelp.loc[Merge_table_Yelp["Stars"] == 1, "Class"] = "Negative"
Merge_table_Yelp.loc[Merge_table_Yelp["Stars"] == 2, "Class"] = "Negative"
Merge_table_Yelp.loc[Merge_table_Yelp["Stars"] == 3, "Class"] = "Neutral"
Merge_table_Yelp.loc[Merge_table_Yelp["Stars"] == 4, "Class"] = "Positive"
Merge_table_Yelp.loc[Merge_table_Yelp["Stars"] == 5, "Class"] = "Positive"

Merge_table_Yelp["Stars"] = Merge_table_Yelp["Stars"].astype(np.int64)

Merge_table_Yelp["Review_Source"] = "Yelp"

Merge_table_Yelp = Merge_table_Yelp[['City', 'Stars', 'Class', 'Review_Source', 'Review_Date', 'Review_Text']]
    
Merge_table_Yelp.to_csv("./Resources/Merge_table_Yelp.csv", index=False)

Merge_table_Yelp.head()
# Out:
#   City  Stars     Class Review_Source Review_Date  \
# 0  NYC      5  Positive          Yelp  05/27/2018
# 1  NYC      1  Negative          Yelp  11/02/2018
# 2  NYC      1  Negative          Yelp  12/23/2018
# 3  NYC      2  Negative          Yelp  04/23/2019
# 4  NYC      1  Negative          Yelp  03/12/2019
#
#                                          Review_Text
# 0  It's not perfect, but I see Citibike as basica...
# 1  Beware when signing up for the annual membersh...
# 2  This used to be a nice town. This use to be a ...
# 3  I think Citibike is a wonderful service for th...
# 4  Not happy to be charged extra for using the el...

# %%
Merge_table_Yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 777 entries, 0 to 355
# Data columns (total 6 columns):
# City             777 non-null object
# Stars            777 non-null int64
# Class            777 non-null object
# Review_Source    777 non-null object
# Review_Date      777 non-null object
# Review_Text      777 non-null object
# dtypes: int64(1), object(5)
# memory usage: 42.5+ KB

# %%
Merge_table_full = Merge_table_TA.append(Merge_table_Yelp)
Merge_table_full.to_csv("./Resources/Merge_table_full.csv", index=False)

Merge_table_full
# Out:
#         City  Stars     Class Review_Source Review_Date  \
# 0    Chicago      5  Positive   TripAdvisor  04/15/2019
# 1    Chicago      1  Negative   TripAdvisor  03/08/2019
# 2    Chicago      1  Negative   TripAdvisor  02/25/2019
# 3    Chicago      5  Positive   TripAdvisor  02/12/2019
# 4    Chicago      2  Negative   TripAdvisor  01/23/2019
# 5    Chicago      4  Positive   TripAdvisor  12/23/2018
# 6    Chicago      1  Negative   TripAdvisor  11/12/2018
# 7    Chicago      1  Negative   TripAdvisor  10/29/2018
# 8    Chicago      4  Positive   TripAdvisor  10/08/2018
# 9    Chicago      5  Positive   TripAdvisor  09/24/2018
# 10   Chicago      1  Negative   TripAdvisor  09/16/2018
# 11   Chicago      3   Neutral   TripAdvisor  09/12/2018
# 12   Chicago      3   Neutral   TripAdvisor  09/11/2018
# 13   Chicago      4  Positive   TripAdvisor  09/06/2018
# 14   Chicago      3   Neutral   TripAdvisor  08/31/2018
# 15   Chicago      4  Positive   TripAdvisor  08/27/2018
# 16   Chicago      5  Positive   TripAdvisor  08/25/2018
# 17   Chicago      5  Positive   TripAdvisor  08/21/2018
# 18   Chicago      5  Positive   TripAdvisor  08/14/2018
# 19   Chicago      5  Positive   TripAdvisor  08/03/2018
# 20   Chicago      5  Positive   TripAdvisor  08/02/2018
# 21   Chicago      3   Neutral   TripAdvisor  07/29/2018
# 22   Chicago      2  Negative   TripAdvisor  07/27/2018
# 23   Chicago      5  Positive   TripAdvisor  07/22/2018
# 24   Chicago      2  Negative   TripAdvisor  07/19/2018
# 25   Chicago      3   Neutral   TripAdvisor  06/26/2018
# 26   Chicago      5  Positive   TripAdvisor  06/17/2018
# 27   Chicago      2  Negative   TripAdvisor  05/31/2018
# 28   Chicago      4  Positive   TripAdvisor  05/27/2018
# 29   Chicago      5  Positive   TripAdvisor  05/01/2018
# ..       ...    ...       ...           ...         ...
# 326       DC      5  Positive          Yelp  12/17/2014
# 327       DC      5  Positive          Yelp  09/04/2011
# 328       DC      5  Positive          Yelp  09/02/2014
# 329       DC      1  Negative          Yelp  04/03/2012
# 330       DC      1  Negative          Yelp  09/05/2012
# 331       DC      1  Negative          Yelp  07/04/2015
# 332       DC      3   Neutral          Yelp  09/14/2011
# 333       DC      1  Negative          Yelp  06/23/2012
# 334       DC      3   Neutral          Yelp  05/24/2014
# 335       DC      1  Negative          Yelp  05/22/2012
# 336       DC      1  Negative          Yelp  08/30/2011
# 337       DC      4  Positive          Yelp  08/28/2013
# 338       DC      1  Negative          Yelp  10/18/2010
# 339       DC      4  Positive          Yelp  07/28/2011
# 340       DC      5  Positive          Yelp  05/20/2013
# 341       DC      2  Negative          Yelp  10/02/2010
# 342       DC      1  Negative          Yelp  08/06/2012
# 343       DC      2  Negative          Yelp  09/26/2011
# 344       DC      4  Positive          Yelp  11/07/2010
# 345       DC      5  Positive          Yelp  04/03/2012
# 346       DC      1  Negative          Yelp  08/05/2013
# 347       DC      5  Positive          Yelp  02/02/2011
# 348       DC      5  Positive          Yelp  05/08/2012
# 349       DC      5  Positive          Yelp  05/20/2013
# 350       DC      1  Negative          Yelp  08/06/2011
# 351       DC      3   Neutral          Yelp  01/20/2012
# 352       DC      4  Positive          Yelp  10/12/2010
# 353       DC      1  Negative          Yelp  04/15/2014
# 354       DC      1  Negative          Yelp  06/29/2012
# 355       DC      2  Negative          Yelp  10/29/2010
